# %% [markdown]
# *Check for any duplicate and if any remove them
#
# *standardise data and fix error

# %% [markdown]
# Data Cleaning In Panadas

# %%
import pandas as pd

# %% [markdown]
# import dataset

# %%
df = pd.read_excel("Datasets/ccl.xlsx")

# %%
df.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# dtype: bool

# %%
df.iloc[20]
# Out:
# CustomerID                                  1020
# First_Name                                Anakin
# Last_Name                              Skywalker
# Phone_Number                        876|678|3469
# Address              910 Tatooine Road, Tatooine
# Paying Customer                              Yes
# Do_Not_Contact                                 N
# Not_Useful_Column                           True
# Name: 20, dtype: object

# %%
df.tail(5)
# Out:
#     CustomerID First_Name  Last_Name  Phone_Number  \
# 16        1017   Michael       Scott  123/643/9775
# 17        1018      Clark       Kent    7066950392
# 18        1019      Creed     Braton           N/a
# 19        1020     Anakin  Skywalker  876|678|3469
# 20        1020     Anakin  Skywalker  876|678|3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 16  121 Paper Avenue, Pennsylvania             Yes             No
# 17                 3498 Super Lane               Y            NaN
# 18                             N/a             N/a            Yes
# 19     910 Tatooine Road, Tatooine             Yes              N
# 20     910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column
# 16              False
# 17               True
# 18               True
# 19               True
# 20               True

# %%
fd
# Out:
# <bound method DataFrame.duplicated of    CustomerID First_Name    Last_Name Phone_Number Paying Customer  \
# 0        1002       Abed        Nadir   1236439775               N
# 1        1003     Walter       /White   7066950392               N
# 2        1008   Sherlock       Holmes   8766783469               N
# 3        1015       Toby  Flenderson_   3047622467               N
# 4        1016        Ron      Weasley   1235455421               N
#
#   Do_Not_Contact        Street_Address City Pin_code
# 0              N   93 West Main Street
# 1              N    298 Drugs Driveway
# 2              N         98 Clue Drive
# 3              N         214 HR Avenue
# 4              N  2395 Hogwarts Avenue                >

# %%
fd = df.duplicated

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df[fd]
# Out:
#     CustomerID First_Name  Last_Name  Phone_Number  \
# 20        1020     Anakin  Skywalker  876|678|3469
#
#                         Address Paying Customer Do_Not_Contact  \
# 20  910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column
# 20               True

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum
# Out:
# <bound method Series.sum of 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool>

# %%
df['Phone_Number']
# Out:
# 0     123-545-5421
# 1     123/643/9775
# 2       7066950392
# 3     123-543-2345
# 4     876|678|3469
# 5     304-762-2467
# 6              NaN
# 7     876|678|3469
# 8              N/a
# 9     123-545-5421
# 10             NaN
# 11      7066950392
# 12    123-543-2345
# 13    876|678|3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123/643/9775
# 17      7066950392
# 18             N/a
# 19    876|678|3469
# Name: Phone_Number, dtype: object

# %% [markdown]
# Step2

# %%
df.columns
# Out:
# Index(['CustomerID', 'First_Name', 'Last_Name', 'Phone_Number', 'Address',
#        'Paying Customer', 'Do_Not_Contact', 'Not_Useful_Column'],
#       dtype='object')

# %%
df['Last_Name']
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
ln ="...Poter"
ln.strip()
# Out:
# '...Poter'

# %%
df['Last_Name'].str.strip()
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df['Last_Name'].str.strip("123._/")
# Out:
# 0        Baggins
# 1          Nadir
# 2          White
# 3        Schrute
# 4           Snow
# 5        Swanson
# 6         Winger
# 7         Holmes
# 8            NaN
# 9         Parker
# 10        Gamgee
# 11        Potter
# 12        Draper
# 13         Knope
# 14    Flenderson
# 15       Weasley
# 16         Scott
# 17          Kent
# 18        Braton
# 19     Skywalker
# Name: Last_Name, dtype: object

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %% [markdown]
# STEP TO MAKE ALL NUMBER IN THE PHONENUMBER COLUMN TO BE OF SAME LENGTH AND format
# STEP1 - REPLACE ALL THE UNWANTED CHACTERS TO EMPTY STRING(")")

# %% [markdown]
# #python string

# %%
name = "mike-tyson" 
name=name.replace("_","")

# %%
df.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %%
df['Phone_Number']
# Out:
# 0     123-545-5421
# 1     123/643/9775
# 2       7066950392
# 3     123-543-2345
# 4     876|678|3469
# 5     304-762-2467
# 6              NaN
# 7     876|678|3469
# 8              N/a
# 9     123-545-5421
# 10             NaN
# 11      7066950392
# 12    123-543-2345
# 13    876|678|3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123/643/9775
# 17      7066950392
# 18             N/a
# 19    876|678|3469
# Name: Phone_Number, dtype: object

# %%
df['Phone_Number'].str.replace("[^0-9]","",regex=True)
# Out:
# 0     1235455421
# 1     1236439775
# 2            NaN
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6            NaN
# 7     8766783469
# 8
# 9     1235455421
# 10           NaN
# 11           NaN
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17           NaN
# 18
# 19    8766783469
# Name: Phone_Number, dtype: object

# %%
df['Phone_Number'].str.replace("[^0-9]","",regex=True)
# Out:
# 0     1235455421
# 1     1236439775
# 2            NaN
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6            NaN
# 7     8766783469
# 8
# 9     1235455421
# 10           NaN
# 11           NaN
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17           NaN
# 18
# 19    8766783469
# Name: Phone_Number, dtype: object

# %%
l1 = lambda x:x[0:3]+"-"+x[3:6]+"-"+x[6:10]
l1("1234567890")
# Out:
# '123-456-7890'

# %% [markdown]
# ### apply ()=>Apply is a pandas function which will apply specified funcationality to each value of series

# %%
df['Phone_Number']=df['Phone_Number'].apply(lambda x : str(x))

# %%
df['Phone_Number']
# Out:
# 0     123-545-5421
# 1     123/643/9775
# 2       7066950392
# 3     123-543-2345
# 4     876|678|3469
# 5     304-762-2467
# 6              nan
# 7     876|678|3469
# 8              N/a
# 9     123-545-5421
# 10             nan
# 11      7066950392
# 12    123-543-2345
# 13    876|678|3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123/643/9775
# 17      7066950392
# 18             N/a
# 19    876|678|3469
# Name: Phone_Number, dtype: object

# %%
df['Phone_Number']=df['Phone_Number'].str.replace("[^0-9]","",regex=True)

# %%
df['Phone_Number']
# Out:
# 0     1235455421
# 1     1236439775
# 2     7066950392
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6
# 7     8766783469
# 8
# 9     1235455421
# 10
# 11    7066950392
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17    7066950392
# 18
# 19    8766783469
# Name: Phone_Number, dtype: object

# %%
# i want to appdf['Ply the above lambda functoin to all the values in the phone number column
type(df['Phone_Number'][17])
# Out:
# str

# %%
df['Phone_Number']=df['Phone_Number'].apply(l1)

# %%
l1 = lambda x:x[0:3]+"-"+x[3:6]+"-"+x[6:10]

# %%
df['Phone_Number']=df['Phone_Number'].str.replace("[^0-9]","",regex=True)

# %%
df['Phone_Number']=df['Phone_Number'].apply(lambda x : str(x))

# %%
df['Phone_Number']=df['Phone_Number'].str.replace("[^0-9]","",regex=True)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name Phone_Number  \
# 0         1001      Frodo      Baggins   1235455421
# 1         1002       Abed        Nadir   1236439775
# 2         1003     Walter       /White   7066950392
# 3         1004     Dwight      Schrute   1235432345
# 4         1005        Jon         Snow   8766783469
# 5         1006        Ron      Swanson   3047622467
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes   8766783469
# 8         1009    Gandalf          NaN
# 9         1010      Peter       Parker   1235455421
# 10        1011    Samwise       Gamgee
# 11        1012      Harry    ...Potter   7066950392
# 12        1013        Don       Draper   1235432345
# 13        1014     Leslie        Knope   8766783469
# 14        1015       Toby  Flenderson_   3047622467
# 15        1016        Ron      Weasley   1235455421
# 16        1017   Michael         Scott   1236439775
# 17        1018      Clark         Kent   7066950392
# ...

# %%
## address
df['Address']
# Out:
# 0                     123 Shire Lane, Shire
# 1                       93 West Main Street
# 2                        298 Drugs Driveway
# 3     980 Paper Avenue, Pennsylvania, 18503
# 4                          123 Dragons Road
# 5                          768 City Parkway
# 6                         1209 South Street
# 7                             98 Clue Drive
# 8                          123 Middle Earth
# 9                25th Main Street, New York
# 10                    612 Shire Lane, Shire
# 11                     2394 Hogwarts Avenue
# 12                         2039 Main Street
# 13                         343 City Parkway
# 14                            214 HR Avenue
# 15                     2395 Hogwarts Avenue
# 16           121 Paper Avenue, Pennsylvania
# 17                          3498 Super Lane
# 18                                      N/a
# 19              910 Tatooine Road, Tatooine
# Name: Address, dtype: object

# %%
## address
df['Address'].str.split(',',expand=True)
# Out:
#                        0              1       2
# 0         123 Shire Lane          Shire    None
# 1    93 West Main Street           None    None
# 2     298 Drugs Driveway           None    None
# 3       980 Paper Avenue   Pennsylvania   18503
# 4       123 Dragons Road           None    None
# 5       768 City Parkway           None    None
# 6      1209 South Street           None    None
# 7          98 Clue Drive           None    None
# 8       123 Middle Earth           None    None
# 9       25th Main Street       New York    None
# 10        612 Shire Lane          Shire    None
# 11  2394 Hogwarts Avenue           None    None
# 12      2039 Main Street           None    None
# 13      343 City Parkway           None    None
# 14         214 HR Avenue           None    None
# 15  2395 Hogwarts Avenue           None    None
# 16      121 Paper Avenue   Pennsylvania    None
# 17       3498 Super Lane           None    None
# 18                   N/a           None    None
# ...

# %%
fullname ="Virat, Kholi"
fullname.split(',')
# Out:
# ['Virat', ' Kholi']

# %%
#spliting address into 3 step cols
df[['Street_Address','City','Pin_code']]=df['Address'].str.split(',',expand=True)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name Phone_Number  \
# 0         1001      Frodo      Baggins   1235455421
# 1         1002       Abed        Nadir   1236439775
# 2         1003     Walter       /White   7066950392
# 3         1004     Dwight      Schrute   1235432345
# 4         1005        Jon         Snow   8766783469
# 5         1006        Ron      Swanson   3047622467
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes   8766783469
# 8         1009    Gandalf          NaN
# 9         1010      Peter       Parker   1235455421
# 10        1011    Samwise       Gamgee
# 11        1012      Harry    ...Potter   7066950392
# 12        1013        Don       Draper   1235432345
# 13        1014     Leslie        Knope   8766783469
# 14        1015       Toby  Flenderson_   3047622467
# 15        1016        Ron      Weasley   1235455421
# 16        1017   Michael         Scott   1236439775
# 17        1018      Clark         Kent   7066950392
# ...

# %%
df['Paying Customer']=df['Paying Customer'].str.replace('Yes','Y')

# %%
df['Paying Customer']=df['Paying Customer'].str.replace('No','N')

# %%
df['Paying Customer']
# Out:
# 0       Y
# 1       N
# 2       N
# 3       Y
# 4       Y
# 5       Y
# 6       N
# 7       N
# 8       Y
# 9       Y
# 10      Y
# 11      Y
# 12      Y
# 13      Y
# 14      N
# 15      N
# 16      Y
# 17      Y
# 18    N/a
# 19      Y
# Name: Paying Customer, dtype: object

# %%
df.columns
# Out:
# Index(['CustomerID', 'First_Name', 'Last_Name', 'Phone_Number', 'Address',
#        'Paying Customer', 'Do_Not_Contact', 'Not_Useful_Column',
#        'Street_Address', 'City', 'Pin_code'],
#       dtype='object')

# %%
df['Do_Not_Contact']=df['Do_Not_Contact'].str.replace('Yes','Y')
df['Do_Not_Contact']=df['Do_Not_Contact'].str.replace('No','N')

# %%
df['Do_Not_Contact']
# Out:
# 0       N
# 1       Y
# 2     NaN
# 3       Y
# 4       N
# 5       Y
# 6       N
# 7       N
# 8     NaN
# 9       N
# 10      N
# 11    NaN
# 12      N
# 13      N
# 14      N
# 15      N
# 16      N
# 17    NaN
# 18      Y
# 19      N
# Name: Do_Not_Contact, dtype: object

# %%
# remove columns
df.drop(columns=['Not_Useful_Column','Address'],inplace=True)

# %% [markdown]
# #### Dealing with  null values

# %%
df.replace('N/a','',inplace=True)
df.replace('NaN','',inplace=True)

# %%
df.replace('--','',inplace=True)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo      Baggins   1235455421               Y
# 1         1002       Abed        Nadir   1236439775               N
# 2         1003     Walter       /White   7066950392               N
# 3         1004     Dwight      Schrute   1235432345               Y
# 4         1005        Jon         Snow   8766783469               Y
# 5         1006        Ron      Swanson   3047622467               Y
# 6         1007       Jeff       Winger                            N
# 7         1008   Sherlock       Holmes   8766783469               N
# 8         1009    Gandalf          NaN                            Y
# 9         1010      Peter       Parker   1235455421               Y
# 10        1011    Samwise       Gamgee                            Y
# 11        1012      Harry    ...Potter   7066950392               Y
# 12        1013        Don       Draper   1235432345               Y
# ...

# %%
df.fillna('A')
# Out:
#     CustomerID First_Name    Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo      Baggins   1235455421               Y
# 1         1002       Abed        Nadir   1236439775               N
# 2         1003     Walter       /White   7066950392               N
# 3         1004     Dwight      Schrute   1235432345               Y
# 4         1005        Jon         Snow   8766783469               Y
# 5         1006        Ron      Swanson   3047622467               Y
# 6         1007       Jeff       Winger                            N
# 7         1008   Sherlock       Holmes   8766783469               N
# 8         1009    Gandalf            A                            Y
# 9         1010      Peter       Parker   1235455421               Y
# 10        1011    Samwise       Gamgee                            Y
# 11        1012      Harry    ...Potter   7066950392               Y
# 12        1013        Don       Draper   1235432345               Y
# ...

# %%
df.fillna('',inplace=True)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo      Baggins   1235455421               Y
# 1         1002       Abed        Nadir   1236439775               N
# 2         1003     Walter       /White   7066950392               N
# 3         1004     Dwight      Schrute   1235432345               Y
# 4         1005        Jon         Snow   8766783469               Y
# 5         1006        Ron      Swanson   3047622467               Y
# 6         1007       Jeff       Winger                            N
# 7         1008   Sherlock       Holmes   8766783469               N
# 8         1009    Gandalf                                         Y
# 9         1010      Peter       Parker   1235455421               Y
# 10        1011    Samwise       Gamgee                            Y
# 11        1012      Harry    ...Potter   7066950392               Y
# 12        1013        Don       Draper   1235432345               Y
# ...

# %%
for i in df.index:
    if df.loc[i,'Do_Not_Contact'] =="Y" or df.loc[i,'Phone_Number'] =="":
        df.drop(i,inplace=True)

# %%
df.reset_index(inplace=True,drop=True)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo      Baggins   1235455421               Y
# 1         1003     Walter       /White   7066950392               N
# 2         1005        Jon         Snow   8766783469               Y
# 3         1008   Sherlock       Holmes   8766783469               N
# 4         1010      Peter       Parker   1235455421               Y
# 5         1012      Harry    ...Potter   7066950392               Y
# 6         1013        Don       Draper   1235432345               Y
# 7         1014     Leslie        Knope   8766783469               Y
# 8         1015       Toby  Flenderson_   3047622467               N
# 9         1016        Ron      Weasley   1235455421               N
# 10        1017   Michael         Scott   1236439775               Y
# 11        1018      Clark         Kent   7066950392               Y
# 12        1020     Anakin    Skywalker   8766783469               Y
#
# ...
